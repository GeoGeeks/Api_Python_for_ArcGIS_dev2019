# %%
pd.options.display.max_rows = 10

# %%
import pandas as pd
from arcgis.gis import GIS
from pathlib import Path
from zipfile import ZipFile
from arcgis.features import FeatureLayer
import numpy as np

# %% [markdown]
# https://www.datos.gov.co/Estad-sticas-Nacionales/Entradas-de-extranjeros-a-Colombia/96sh-4v8d

# %%
df = pd.read_csv("Entradas_de_extranjeros_a_Colombia.csv",dtype={'Nueva columna georreferenciada':'str'})
df=df.dropna(axis=0, subset=['Nueva columna georreferenciada'])
df=df[df['Nacionalidad'] == 'Venezuela']
df
# Out:
#         Año    Mes Nacionalidad  Femenino  Masculino  Indefinido  Total  \
# 907    2012  Enero    Venezuela       297        339         NaN    636
# 908    2012  Enero    Venezuela         7         12         NaN     19
# 909    2012  Enero    Venezuela        76        133         NaN    209
# 910    2012  Enero    Venezuela        55         70         NaN    125
# 911    2012  Enero    Venezuela         0          4         NaN      4
# ...     ...    ...          ...       ...        ...         ...    ...
# 67653  2019  Junio    Venezuela         9         13         NaN     22
# 67654  2019  Junio    Venezuela     29976      26826         NaN  56802
# 67655  2019  Junio    Venezuela        12         28         NaN     40
# 67656  2019  Junio    Venezuela      1904       1597         NaN   3501
# 67657  2019  Junio    Venezuela         1          0         NaN      1
#
#       Nueva columna georreferenciada
# 907           POINT (0.81488 -77356)
# 908       POINT (10406342 -75527794)
# 909       POINT (10446304 -75516486)
# 910       POINT (10886686 -74776479)
# 911       POINT (11117206 -74232675)
# ...                              ...
# 67653      POINT (7128047 -73181317)
# 67654         POINT (7819 -72453013)
# 67655      POINT (7927233 -72508188)
# 67656       POINT (836068 -72409396)
# 67657        POINT (863337 -7735002)
#
# [1734 rows x 8 columns]

# %%
lonlat=(df
           .apply(lambda row: row['Nueva columna georreferenciada'],axis=1)
           .apply(lambda word: word.replace('POINT (',''))
           .apply(lambda body: list(body))
           .apply(lambda letters: list(map(lambda letter:letter.replace(")",''),letters)))
           .apply(lambda letters: ''.join(letters))
              )            

df['lat long']=lonlat
df
# Out:
#         Año    Mes Nacionalidad  Femenino  Masculino  Indefinido  Total  \
# 907    2012  Enero    Venezuela       297        339         NaN    636
# 908    2012  Enero    Venezuela         7         12         NaN     19
# 909    2012  Enero    Venezuela        76        133         NaN    209
# 910    2012  Enero    Venezuela        55         70         NaN    125
# 911    2012  Enero    Venezuela         0          4         NaN      4
# ...     ...    ...          ...       ...        ...         ...    ...
# 67653  2019  Junio    Venezuela         9         13         NaN     22
# 67654  2019  Junio    Venezuela     29976      26826         NaN  56802
# 67655  2019  Junio    Venezuela        12         28         NaN     40
# 67656  2019  Junio    Venezuela      1904       1597         NaN   3501
# 67657  2019  Junio    Venezuela         1          0         NaN      1
#
#       Nueva columna georreferenciada            lat long
# 907           POINT (0.81488 -77356)      0.81488 -77356
# 908       POINT (10406342 -75527794)  10406342 -75527794
# 909       POINT (10446304 -75516486)  10446304 -75516486
# 910       POINT (10886686 -74776479)  10886686 -74776479
# 911       POINT (11117206 -74232675)  11117206 -74232675
# ...                              ...                 ...
# 67653      POINT (7128047 -73181317)   7128047 -73181317
# 67654         POINT (7819 -72453013)      7819 -72453013
# 67655      POINT (7927233 -72508188)   7927233 -72508188
# 67656       POINT (836068 -72409396)    836068 -72409396
# 67657        POINT (863337 -7735002)     863337 -7735002
#
# [1734 rows x 9 columns]

# %%
df.iloc[18]
# Out:
# Año                                                     2012
# Mes                                                  Febrero
# Nacionalidad                                       Venezuela
# Femenino                                                   0
# Masculino                                                  3
#                                              ...
# Total                                                      3
# Nueva columna georreferenciada    POINT (-4191162 -69941498)
# lonlat                                    -4191162 -69941498
# latt                                                     NaN
# lonn                                                     NaN
# Name: 1883, Length: 11, dtype: object

# %%
latlon_df = df['lat long'].apply(lambda x: pd.Series(x.split(' ')))
df['latt']=latlon_df[0]
df['lonn']=latlon_df[1]
df
# Out:
#         Año    Mes Nacionalidad  Femenino  Masculino  Indefinido  Total  \
# 907    2012  Enero    Venezuela       297        339         NaN    636
# 908    2012  Enero    Venezuela         7         12         NaN     19
# 909    2012  Enero    Venezuela        76        133         NaN    209
# 910    2012  Enero    Venezuela        55         70         NaN    125
# 911    2012  Enero    Venezuela         0          4         NaN      4
# ...     ...    ...          ...       ...        ...         ...    ...
# 67653  2019  Junio    Venezuela         9         13         NaN     22
# 67654  2019  Junio    Venezuela     29976      26826         NaN  56802
# 67655  2019  Junio    Venezuela        12         28         NaN     40
# 67656  2019  Junio    Venezuela      1904       1597         NaN   3501
# 67657  2019  Junio    Venezuela         1          0         NaN      1
#
#       Nueva columna georreferenciada            lat long      latt       lonn
# 907           POINT (0.81488 -77356)      0.81488 -77356   0.81488     -77356
# 908       POINT (10406342 -75527794)  10406342 -75527794  10406342  -75527794
# 909       POINT (10446304 -75516486)  10446304 -75516486  10446304  -75516486
# 910       POINT (10886686 -74776479)  10886686 -74776479  10886686  -74776479
# 911       POINT (11117206 -74232675)  11117206 -74232675  11117206  -74232675
# ...                              ...                 ...       ...        ...
# 67653      POINT (7128047 -73181317)   7128047 -73181317   7128047  -73181317
# 67654         POINT (7819 -72453013)      7819 -72453013      7819  -72453013
# 67655      POINT (7927233 -72508188)   7927233 -72508188   7927233  -72508188
# 67656       POINT (836068 -72409396)    836068 -72409396    836068  -72409396
# 67657        POINT (863337 -7735002)     863337 -7735002    863337   -7735002
#
# [1734 rows x 11 columns]

# %%
df=df.drop(['lat long', 'Nueva columna georreferenciada'], axis=1)
df
# Out:
#         Año    Mes Nacionalidad  Femenino  Masculino  Indefinido  Total  \
# 907    2012  Enero    Venezuela       297        339         NaN    636
# 908    2012  Enero    Venezuela         7         12         NaN     19
# 909    2012  Enero    Venezuela        76        133         NaN    209
# 910    2012  Enero    Venezuela        55         70         NaN    125
# 911    2012  Enero    Venezuela         0          4         NaN      4
# ...     ...    ...          ...       ...        ...         ...    ...
# 67653  2019  Junio    Venezuela         9         13         NaN     22
# 67654  2019  Junio    Venezuela     29976      26826         NaN  56802
# 67655  2019  Junio    Venezuela        12         28         NaN     40
# 67656  2019  Junio    Venezuela      1904       1597         NaN   3501
# 67657  2019  Junio    Venezuela         1          0         NaN      1
#
#            latt       lonn        long
# 907     0.81488     -77356     -77.356
# 908    10406342  -75527794  -75.527794
# 909    10446304  -75516486  -75.516486
# 910    10886686  -74776479  -74.776479
# 911    11117206  -74232675  -74.232675
# ...         ...        ...         ...
# 67653   7128047  -73181317  -73.181317
# 67654      7819  -72453013  -72.453013
# 67655   7927233  -72508188  -72.508188
# 67656    836068  -72409396  -72.409396
# 67657    863337   -7735002   -77.35002
#
# [1734 rows x 10 columns]

# %%
df = pd.read_csv("Libro1.csv", sep=';',dtype={'columna':'str','georreferenciada':'str'})
df=df.dropna(axis=0, subset=['georreferenciada'])
df=df.dropna(axis=0, subset=['columna'])
df
# Out:
#        Año    Mes Nacionalidad  Femenino  Masculino  Indefinido    Total  \
# 0     2012  Enero    Venezuela     297.0      339.0         NaN    636.0
# 1     2012  Enero    Venezuela       7.0       12.0         NaN     19.0
# 2     2012  Enero    Venezuela      76.0      133.0         NaN    209.0
# 3     2012  Enero    Venezuela      55.0       70.0         NaN    125.0
# 4     2012  Enero    Venezuela       0.0        4.0         NaN      4.0
# ...    ...    ...          ...       ...        ...         ...      ...
# 1729  2019  Junio    Venezuela       9.0       13.0         NaN     22.0
# 1730  2019  Junio    Venezuela   29976.0    26826.0         NaN  56802.0
# 1731  2019  Junio    Venezuela      12.0       28.0         NaN     40.0
# 1732  2019  Junio    Venezuela    1904.0     1597.0         NaN   3501.0
# 1733  2019  Junio    Venezuela       1.0        0.0         NaN      1.0
#
#       Nueva   columna georreferenciada
# 0     POINT   0.81488           -77356
# 1     POINT  10406342        -75527794
# 2     POINT  10446304        -75516486
# 3     POINT  10886686        -74776479
# 4     POINT  11117206        -74232675
# ...     ...       ...              ...
# 1729  POINT   7128047        -73181317
# 1730  POINT      7819        -72453013
# 1731  POINT   7927233        -72508188
# 1732  POINT    836068        -72409396
# 1733  POINT    863337         -7735002
#
# [1734 rows x 10 columns]

# %%
df=df.dropna(axis=0, subset=['latt'])
df=df.dropna(axis=0, subset=['lonn'])
df
# Out:
#         Año    Mes Nacionalidad  Femenino  Masculino  Indefinido  Total  \
# 907    2012  Enero    Venezuela       297        339         NaN    636
# 908    2012  Enero    Venezuela         7         12         NaN     19
# 909    2012  Enero    Venezuela        76        133         NaN    209
# 910    2012  Enero    Venezuela        55         70         NaN    125
# 911    2012  Enero    Venezuela         0          4         NaN      4
# ...     ...    ...          ...       ...        ...         ...    ...
# 67653  2019  Junio    Venezuela         9         13         NaN     22
# 67654  2019  Junio    Venezuela     29976      26826         NaN  56802
# 67655  2019  Junio    Venezuela        12         28         NaN     40
# 67656  2019  Junio    Venezuela      1904       1597         NaN   3501
# 67657  2019  Junio    Venezuela         1          0         NaN      1
#
#            latt       lonn  long
# 907     0.81488     -77356     0
# 908    10406342  -75527794     0
# 909    10446304  -75516486     0
# 910    10886686  -74776479     0
# 911    11117206  -74232675     0
# ...         ...        ...   ...
# 67653   7128047  -73181317     0
# 67654      7819  -72453013     0
# 67655   7927233  -72508188     0
# 67656    836068  -72409396     0
# 67657    863337   -7735002     0
#
# [1734 rows x 10 columns]

# %%
long=df['lonn']
df['long']=0
for i in range(1734):
     df['long'].iloc[i]=(long.iloc[i])[0:3]+'.'+(long.iloc[i])[3:]
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#         Año    Mes Nacionalidad  Femenino  Masculino  Indefinido  Total  \
# 907    2012  Enero    Venezuela       297        339         NaN    636
# 908    2012  Enero    Venezuela         7         12         NaN     19
# 909    2012  Enero    Venezuela        76        133         NaN    209
# 910    2012  Enero    Venezuela        55         70         NaN    125
# 911    2012  Enero    Venezuela         0          4         NaN      4
# ...     ...    ...          ...       ...        ...         ...    ...
# 67653  2019  Junio    Venezuela         9         13         NaN     22
# 67654  2019  Junio    Venezuela     29976      26826         NaN  56802
# 67655  2019  Junio    Venezuela        12         28         NaN     40
# 67656  2019  Junio    Venezuela      1904       1597         NaN   3501
# 67657  2019  Junio    Venezuela         1          0         NaN      1
#
#            latt       lonn        long
# 907     0.81488     -77356     -77.356
# 908    10406342  -75527794  -75.527794
# 909    10446304  -75516486  -75.516486
# 910    10886686  -74776479  -74.776479
# 911    11117206  -74232675  -74.232675
# ...         ...        ...         ...
# 67653   7128047  -73181317  -73.181317
# 67654      7819  -72453013  -72.453013
# 67655   7927233  -72508188  -72.508188
# 67656    836068  -72409396  -72.409396
# 67657    863337   -7735002   -77.35002
#
# [1734 rows x 10 columns]

# %%
df
# Out:
#         Año    Mes Nacionalidad  Femenino  Masculino  Indefinido  Total  \
# 907    2012  Enero    Venezuela       297        339         NaN    636
# 908    2012  Enero    Venezuela         7         12         NaN     19
# 909    2012  Enero    Venezuela        76        133         NaN    209
# 910    2012  Enero    Venezuela        55         70         NaN    125
# 911    2012  Enero    Venezuela         0          4         NaN      4
# ...     ...    ...          ...       ...        ...         ...    ...
# 67653  2019  Junio    Venezuela         9         13         NaN     22
# 67654  2019  Junio    Venezuela     29976      26826         NaN  56802
# 67655  2019  Junio    Venezuela        12         28         NaN     40
# 67656  2019  Junio    Venezuela      1904       1597         NaN   3501
# 67657  2019  Junio    Venezuela         1          0         NaN      1
#
#            latt       lonn        long  lati  lat
# 907     0.81488     -77356     -77.356     0    0
# 908    10406342  -75527794  -75.527794     0    0
# 909    10446304  -75516486  -75.516486     0    0
# 910    10886686  -74776479  -74.776479     0    0
# 911    11117206  -74232675  -74.232675     0    0
# ...         ...        ...         ...   ...  ...
# 67653   7128047  -73181317  -73.181317     0    0
# 67654      7819  -72453013  -72.453013     0    0
# 67655   7927233  -72508188  -72.508188     0    0
# 67656    836068  -72409396  -72.409396     0    0
# 67657    863337   -7735002   -77.35002     0    0
#
# [1734 rows x 12 columns]

# %%
lat=df['latt']
df['lat']=0
for i in range(1734):
    if (lat.iloc[i])[0]=='1':
        df['lat'].iloc[i]=(lat.iloc[i])[0:2]+'.'+(lat.iloc[i])[2:]
    elif (lat.iloc[i])[0]=='-':
        df['lat'].iloc[i]=(lat.iloc[i])[1:2]+'.'+(lat.iloc[i])[2:]
    elif (lat.iloc[i])[0]=='0':
        df['lat'].iloc[i]=(lat.iloc[i])[0:1]+'.'+(lat.iloc[i])[2:]
    else:
        df['lat'].iloc[i]=(lat.iloc[i])[0:1]+'.'+(lat.iloc[i])[1:]

# %%
df= df.drop(columns=['latt', 'lonn'], axis=1)
df
# Out:
#         Año    Mes Nacionalidad  Femenino  Masculino  Indefinido  Total  \
# 907    2012  Enero    Venezuela       297        339         NaN    636
# 908    2012  Enero    Venezuela         7         12         NaN     19
# 909    2012  Enero    Venezuela        76        133         NaN    209
# 910    2012  Enero    Venezuela        55         70         NaN    125
# 911    2012  Enero    Venezuela         0          4         NaN      4
# ...     ...    ...          ...       ...        ...         ...    ...
# 67653  2019  Junio    Venezuela         9         13         NaN     22
# 67654  2019  Junio    Venezuela     29976      26826         NaN  56802
# 67655  2019  Junio    Venezuela        12         28         NaN     40
# 67656  2019  Junio    Venezuela      1904       1597         NaN   3501
# 67657  2019  Junio    Venezuela         1          0         NaN      1
#
#              long        lat
# 907       -77.356    0.81488
# 908    -75.527794  10.406342
# 909    -75.516486  10.446304
# 910    -74.776479  10.886686
# 911    -74.232675  11.117206
# ...           ...        ...
# 67653  -73.181317   7.128047
# 67654  -72.453013      7.819
# 67655  -72.508188   7.927233
# 67656  -72.409396    8.36068
# 67657   -77.35002    8.63337
#
# [1734 rows x 9 columns]

# %%
df[['long','lat']] = df[['long','lat']].apply(pd.to_numeric)
df
# Out:
#         Año    Mes Nacionalidad  Femenino  Masculino  Indefinido  Total  \
# 907    2012  Enero    Venezuela       297        339         NaN    636
# 908    2012  Enero    Venezuela         7         12         NaN     19
# 909    2012  Enero    Venezuela        76        133         NaN    209
# 910    2012  Enero    Venezuela        55         70         NaN    125
# 911    2012  Enero    Venezuela         0          4         NaN      4
# ...     ...    ...          ...       ...        ...         ...    ...
# 67653  2019  Junio    Venezuela         9         13         NaN     22
# 67654  2019  Junio    Venezuela     29976      26826         NaN  56802
# 67655  2019  Junio    Venezuela        12         28         NaN     40
# 67656  2019  Junio    Venezuela      1904       1597         NaN   3501
# 67657  2019  Junio    Venezuela         1          0         NaN      1
#
#             long        lat
# 907   -77.356000   0.814880
# 908   -75.527794  10.406342
# 909   -75.516486  10.446304
# 910   -74.776479  10.886686
# 911   -74.232675  11.117206
# ...          ...        ...
# 67653 -73.181317   7.128047
# 67654 -72.453013   7.819000
# 67655 -72.508188   7.927233
# 67656 -72.409396   8.360680
# 67657 -77.350020   8.633370
#
# [1734 rows x 9 columns]

# %%
df.dtypes
# Out:
# Año               int64
# Mes              object
# Nacionalidad     object
# Femenino          int64
# Masculino         int64
# Indefinido      float64
# Total             int64
# long            float64
# lat             float64
# dtype: object

# %%
df.to_csv('venezuelafinal2.csv', sep=',', encoding='utf-8')

# %%
df2 = pd.DataFrame(pd.read_csv("venezuelafinal.csv"))
df2.dtypes
# Out:
# Unnamed: 0        int64
# Año               int64
# Mes              object
# Nacionalidad     object
# Femenino        float64
# Masculino       float64
# Indefinido      float64
# Total           float64
# long            float64
# lat             float64
# dtype: object

# %%
gis = GIS("https://www.arcgis.com", username="rcmartinb", password="rcmbcpmb1526")

# %%
venezuela_properties = {
    'title': 'Venezolanos',
    'tags': ['migracion1','migracion2'],
    'type': 'CSV'
}
venezuela_file_location = 'venezuelafinal.csv'
venezuela_csv = gis.content.add(venezuela_properties, data=venezuela_file_location)
venezuela_csv
# Out:
# <Item title:"Venezolanos" type:CSV owner:rcmartinb>

# %%
venezuela_feature_layer_item = venezuela_csv.publish()

# Then visualize the new feature layer

venezuela_feature_layer_item
# Out:
# <Item title:"Venezolanos" type:Feature Layer Collection owner:rcmartinb>

# %%
m = gis.map()

# wait for the map to load, and then add the following in a new cell
m.center = [4, -74]           # `[latitude, longitude]`
m.zoom = 11
m
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=11.0)
# <div class="map-static-img-preview-17f5537f-2bf6-4701-8ce3-46fe62724fe5"><img src=""></img></div>

# %%
query = 'title: "Venezolanos*" AND type: "Feature Service"'
search_results = gis.content.search(query=query, max_items=10)
search_results
# Out:
# [<Item title:"Venezolanos" type:Feature Layer Collection owner:rcmartinb>,
#  <Item title:"Informacion estadistica habitantes venezolanos en la localidad de fontibon_fieldworker" type:Feature Layer Collection owner:jsacevedos_UDFJC>]

# %%
csv_data = search_results[0]
csv_data.url
# Out:
# 'https://services.arcgis.com/deQSb0Gn7gDPf3uV/arcgis/rest/services/Venezolanos/FeatureServer'

# %%
feature_layers = csv_data.layers
trailheads_layer = feature_layers[0]
trailheads_layer.properties.name
# Out:
# 'Venezolanos'
